# %% [markdown]
# # A5
# https://github.com/joshkmartinez/RL-book/tree/master/A5

# %% [markdown]
# # 1
#
# $$ \text{Goal: Maximize } g(S)=p\cdot \int_S^\infty (x-S) \cdot f(x)dx+h \cdot \int_{-\infty}^S (S-x)\cdot f(x)dx
# \newline
# g'(S)=-p \int_S^\infty f(x)dx+h + h\int_{-\infty}^S f(x)dx
# \newline
# \text{Let C be the CDF of }x
# \newline
# g'(S)=-p \cdot(1-C(S))+h\cdot C(S)
# \\
# p \cdot C(S^*)+h\cdot F(S^*) = p \\
# F(S^*)=\frac{p}{p+h} \\
# \therefore  S^* = F^{-1}(\frac{p}{p+h}) \\
# $$
# This problem would be the same to that of managing a portfolio of $p$ number of calls and $h$ number of puts, with the stike price being $K=S$

# %% [markdown]
# # 2

# %%
from dataclasses import dataclass
from typing import TypeVar, Iterable, Callable, Sequence, Tuple, List, Iterator
from rl.policy import DeterministicPolicy
from rl.function_approx import FunctionApprox, LinearFunctionApprox
from rl.approximate_dynamic_programming import back_opt_vf_and_policy, ValueFunctionApprox
from rl.distribution import SampledDistribution, Distribution
from rl.markov_decision_process import MarkovDecisionProcess, NonTerminal, State, Terminal
from rl.distribution import Gaussian

# %%
A = TypeVar('A')
S = TypeVar('S')

class OptionExecution:
    
    def __init__(
        self,
        time_steps: int,
        price_dynamics: Sequence[Callable[[float], Distribution[float]]],
        utility_f: Callable[[float], float],
        γ: float,
        f_approx: ValueFunctionApprox[float],
        strike_price: float,
        price_distribution: Distribution[float],
        is_call: bool # if put then False
    ):
        
        self.time_steps = time_steps
        self.price_dynamics = price_dynamics
        self.utility_f = utility_f
        self.γ = γ
        self.f_approx = f_approx
        self.price_distribution = price_distribution
        self.strike_price = strike_price
        self.is_call = is_call

    def state_distribution(self, t: int) -> SampledDistribution[NonTerminal[float]]:

        def sampler() -> NonTerminal[float]:
            price = float(self.price_distribution.sample())
            
            # sample
            for i in range(t):
                price = self.price_dynamics[i](price).sample()
                
            return NonTerminal(price)

        return SampledDistribution(sampler)
        

    def mdp(self, t: int) -> MarkovDecisionProcess[float, int]:
        utility_f = self.utility_f
        price_dynamics = self.price_dynamics
        steps = self.time_steps
        strike_price = self.strike_price
        is_call = self.is_call
        
        class BinTree(MarkovDecisionProcess[float, str]):
            def __init__(self):
                self.strike_price = strike_price
            
            def step(
                self,
                state: NonTerminal[float],
                action: bool
            ) -> Distribution[Tuple[State[float], float]]:
                    def sampler(
                            prev = state.state
                        ) -> Tuple[State[float], float]:
                            next_price = price_dynamics[t](prev).sample()
                            
                            if not action:
                                reward = float(utility_f(0))
                                next_state = NonTerminal(next_price)
                                
                            else:
                                if is_call:
                                    reward = float(strike_price - next_price)
                                else:
                                    reward = float(next_price - strike_price)
                                    
                                next_state = Terminal(next_price)
                            
                            return (next_state, reward)
                    
                    return SampledDistribution(
                            sampler = sampler,
                            expectation_samples = 50
                        )
                
            def actions(self, state: NonTerminal[S]) -> Iterable[A]:
                return [True, False] # Exercise or not

        return BinTree()

    
    def get_vf_pi(
        self
    ) -> Iterator[Tuple[ValueFunctionApprox[float],
                        DeterministicPolicy[float, bool]]]:
        
        return back_opt_vf_and_policy(
            mdp_f0_mu_triples = [(
                self.mdp(i),
                self.f_approx,
                self.state_distribution(i)
            ) for i in range(self.time_steps)],
            γ = self.γ,
            num_state_samples = 1000,
            error_tolerance = 1e-2 # reasonable value?
        )

# %%
time_steps = 6
mean = 103.0
OptionExecutionTest = OptionExecution(
    time_steps = time_steps,
    
    price_dynamics=[lambda p: Gaussian(
        μ = p,
        σ = 3.0
    ) for i in range(time_steps)],
    
    utility_f = lambda x: x,
    
    γ = 1,
    
    f_approx = LinearFunctionApprox.create(feature_functions=[
        lambda p_s: p_s.state,
    ]),
    
    strike_price = 99.0,
    
    price_distribution=Gaussian(
        # testing
        μ = mean,
        σ = 9.0
    ),
    
    is_call = True #False
)

for step, (v_f, p) in enumerate(OptionExecutionTest.get_vf_pi()):
    print("Time step " + str(step))
    print("Exercise? " + str(p.action_for(mean)))
    print("Value " + str(v_f(NonTerminal(mean))))
    print()
# Out:
# Time step 0
# Exercise? False
# Value 7.263467825733316
#
# Time step 1
# Exercise? False
# Value 6.69429927624563
#
# Time step 2
# Exercise? False
# Value 5.971647358099739
#
# Time step 3
# Exercise? False
# Value 4.902376307865111
#
# Time step 4
# Exercise? False
# Value 3.7287896934822187
#
# Time step 5
# Exercise? False
# Value 1.9278270209978514

# %% [markdown]
# # 3

# %%
from rl.markov_process import MarkovProcess, NonTerminal, State
from rl.distribution import Distribution, Constant, Categorical, Gamma, Poisson, Gaussian, SampledDistribution
from functools import partial
from dataclasses import dataclass
from numpy.random import poisson
from typing import Sequence
import itertools
from rl.chapter9.order_book import OrderBook

# %%
S = OrderBook

class OrderBookDynamics(MarkovProcess[State[S]]):

    def transition(self, state: NonTerminal[S]) -> Distribution[NonTerminal[S]]:
        
        def sampler(state=state):
            
            s = copy.deepcopy(state.state)
            # LO buy
            for _ in range(poisson(3)):
                s = s.buy_limit_order(normal(state.state.bid_price(), 3), int(normal(20, 9)))[1]
            
            # LO sell
            for _ in range(poisson(2)):
                s = s.sell_limit_order(normal(state.state.ask_price(), 6), int(normal(21, 6)))[1]
            
            # MO buy
            for _ in range(poisson(2)):
                s = s.buy_market_order(int(normal(16, 3)))[1]
            
            # MO sell
            for _ in range(poisson(3)):
                s = s.sell_market_order(int(normal(12, 4)))[1]

            return NonTerminal(s)

        return SampledDistribution(sampler=sampler)

# %%
bids: PriceSizePairs = [DollarsAndShares(
    dollars = i,
    shares = poisson(100)) for i in range(100, 85, -1)]
asks: PriceSizePairs = [DollarsAndShares(
    dollars = i,
    shares = poisson(100)) for i in range(100, 135, 1)]

list(itertools.islice(OrderBookMP.simulate(Constant(NonTerminal(OrderBook(descending_bids=bids, ascending_asks=asks)))
), 500))[-1].state.pretty_print_order_book()
# Out:
# Bids
# [DollarsAndShares(dollars=118.20534454614376, shares=17),
#  DollarsAndShares(dollars=115.49351232423284, shares=12),
#  DollarsAndShares(dollars=115.19251323975021, shares=17),
#  DollarsAndShares(dollars=114.58784918989626, shares=21),
#  DollarsAndShares(dollars=114.56109165272171, shares=24),
#  DollarsAndShares(dollars=114.45409459020637, shares=31),
#  DollarsAndShares(dollars=114.40282748887243, shares=15),
#  DollarsAndShares(dollars=114.35910841156421, shares=15),
#  DollarsAndShares(dollars=114.35256435803689, shares=10),
#  DollarsAndShares(dollars=114.25011088731696, shares=34),
#  DollarsAndShares(dollars=114.02103822227878, shares=7),
#  DollarsAndShares(dollars=113.76406805697478, shares=8),
#  DollarsAndShares(dollars=113.76214250498802, shares=1),
#  DollarsAndShares(dollars=113.75025227553353, shares=22),
#  DollarsAndShares(dollars=113.69027520093532, shares=4),
#  DollarsAndShares(dollars=113.29648830295292, shares=9),
#  DollarsAndShares(dollars=113.18374551250552, shares=13),
#  DollarsAndShares(dollars=113.07251158474409, shares=21),
#  DollarsAndShares(dollars=112.9928267725806, shares=23),
#  DollarsAndShares(dollars=112.93106107323807, shares=33),
#  DollarsAndShares(dollars=112.86309818703633, shares=11),
#  DollarsAndShares(dollars=112.820671260578, shares=34),
#  DollarsAndShares(dollars=112.77435244953845, shares=19),
#  DollarsAndShares(dollars=112.64279792386951, shares=14),
#  DollarsAndShares(dollars=112.58408371069672, shares=18),
#  DollarsAndShares(dollars=112.49390531699646, shares=21),
#  DollarsAndShares(dollars=112.45026333320786, shares=26),
#  DollarsAndShares(dollars=112.44258760495123, shares=12),
#  DollarsAndShares(dollars=112.41447545774233, shares=34),
#  DollarsAndShares(dollars=112.38604479017062, shares=26),
#  DollarsAndShares(dollars=112.34668868500164, shares=13),
#  DollarsAndShares(dollars=112.33085353673341, shares=12),
#  DollarsAndShares(dollars=112.30290791912441, shares=6),
#  DollarsAndShares(dollars=112.27168101093487, shares=21),
#  DollarsAndShares(dollars=112.25415405470372, shares=25),
#  DollarsAndShares(dollars=112.24345217736659, shares=9),
#  DollarsAndShares(dollars=112.23357936264429, shares=15),
#  DollarsAndShares(dollars=112.12846775370537, shares=26),
#  DollarsAndShares(dollars=112.07517406025457, shares=20),
#  DollarsAndShares(dollars=112.05846018003038, shares=28),
#  DollarsAndShares(dollars=111.98692034212604, shares=4),
#  DollarsAndShares(dollars=111.98123185957444, shares=17),
#  DollarsAndShares(dollars=111.96715445911812, shares=25),
#  DollarsAndShares(dollars=111.90993355865587, shares=13),
#  DollarsAndShares(dollars=111.84314088661708, shares=27),
#  DollarsAndShares(dollars=111.83837694887706, shares=34),
#  DollarsAndShares(dollars=111.70745713179359, shares=7),
#  DollarsAndShares(dollars=111.70538453592383, shares=20),
#  DollarsAndShares(dollars=111.68731459730682, shares=19),
#  DollarsAndShares(dollars=111.52067180142213, shares=7),
#  DollarsAndShares(dollars=111.50226102384684, shares=3),
#  DollarsAndShares(dollars=111.49216214929446, shares=14),
#  DollarsAndShares(dollars=111.47121723506672, shares=45),
#  DollarsAndShares(dollars=111.46616750830222, shares=28),
#  DollarsAndShares(dollars=111.44600867521292, shares=19),
#  DollarsAndShares(dollars=111.40968318692894, shares=23),
#  DollarsAndShares(dollars=111.37401668233782, shares=14),
#  DollarsAndShares(dollars=111.29552115781553, shares=5),
#  DollarsAndShares(dollars=111.28360565177302, shares=16),
#  DollarsAndShares(dollars=111.26109285775503, shares=16),
#  DollarsAndShares(dollars=111.25933779546855, shares=17),
#  DollarsAndShares(dollars=111.23460493282421, shares=4),
#  DollarsAndShares(dollars=111.21570791853597, shares=26),
#  DollarsAndShares(dollars=111.19534312159222, shares=4),
#  DollarsAndShares(dollars=110.8478008398299, shares=27),
#  DollarsAndShares(dollars=110.75079180966505, shares=25),
#  DollarsAndShares(dollars=110.73781318196251, shares=31),
#  DollarsAndShares(dollars=110.70100194362247, shares=23),
#  DollarsAndShares(dollars=110.62945206649232, shares=14),
#  DollarsAndShares(dollars=110.57010723511769, shares=25),
#  DollarsAndShares(dollars=110.51411094891512, shares=6),
#  DollarsAndShares(dollars=110.50519833302313, shares=27),
#  DollarsAndShares(dollars=110.43964443478794, shares=25),
#  DollarsAndShares(dollars=110.43392151044301, shares=31),
#  DollarsAndShares(dollars=110.42973077926287, shares=28),
#  DollarsAndShares(dollars=110.42340339955422, shares=16),
#  DollarsAndShares(dollars=110.21655101076848, shares=33),
#  DollarsAndShares(dollars=110.14317229868851, shares=38),
#  DollarsAndShares(dollars=110.13720482350831, shares=21),
#  DollarsAndShares(dollars=109.93588535846247, shares=10),
#  DollarsAndShares(dollars=109.82508625567871, shares=9),
#  DollarsAndShares(dollars=109.66879945278819, shares=30),
#  DollarsAndShares(dollars=109.66786530228285, shares=33),
#  DollarsAndShares(dollars=109.54593360660901, shares=16),
#  DollarsAndShares(dollars=109.30870509706364, shares=29),
#  DollarsAndShares(dollars=109.29308791274428, shares=25),
#  DollarsAndShares(dollars=109.25041748230718, shares=24),
#  DollarsAndShares(dollars=109.01502615141031, shares=18),
#  DollarsAndShares(dollars=108.98296408330481, shares=11),
#  DollarsAndShares(dollars=108.95895414995802, shares=15),
#  DollarsAndShares(dollars=108.94651891204488, shares=26),
#  DollarsAndShares(dollars=108.78036559717684, shares=31),
#  DollarsAndShares(dollars=108.74632855080021, shares=27),
#  DollarsAndShares(dollars=108.66352385944847, shares=18),
#  DollarsAndShares(dollars=108.53742710067226, shares=17),
#  DollarsAndShares(dollars=107.9962426521805, shares=6),
#  DollarsAndShares(dollars=107.88039000627919, shares=21),
#  DollarsAndShares(dollars=107.05810294986341, shares=4),
#  DollarsAndShares(dollars=106.92669785103654, shares=22),
#  DollarsAndShares(dollars=106.88659403060304, shares=26),
#  DollarsAndShares(dollars=106.52416661181351, shares=12),
#  DollarsAndShares(dollars=106.5163814863701, shares=2),
#  DollarsAndShares(dollars=106.0594507402641, shares=23),
#  DollarsAndShares(dollars=105.64086509123166, shares=9),
#  DollarsAndShares(dollars=105.61716079038446, shares=11),
#  DollarsAndShares(dollars=105.46733365687696, shares=5),
#  DollarsAndShares(dollars=105.34163657715382, shares=17),
#  DollarsAndShares(dollars=105.25982442961798, shares=9),
#  DollarsAndShares(dollars=105.14736824602596, shares=16),
#  DollarsAndShares(dollars=105.1260390505694, shares=10),
#  DollarsAndShares(dollars=105.0910910801573, shares=20),
#  DollarsAndShares(dollars=105.07536852289694, shares=9),
#  DollarsAndShares(dollars=105.07369631514706, shares=35),
#  DollarsAndShares(dollars=105.072007677813, shares=26),
#  DollarsAndShares(dollars=105.06874462371262, shares=12),
#  DollarsAndShares(dollars=105.0531570720469, shares=14),
#  DollarsAndShares(dollars=105.02350651836127, shares=25),
#  DollarsAndShares(dollars=105.02029749071394, shares=11),
#  DollarsAndShares(dollars=104.9788281285061, shares=15),
#  DollarsAndShares(dollars=104.96943286284123, shares=20),
#  DollarsAndShares(dollars=104.96344419531762, shares=11),
#  DollarsAndShares(dollars=104.96016956849488, shares=23),
#  DollarsAndShares(dollars=104.93621013303975, shares=31),
#  DollarsAndShares(dollars=104.85989532711203, shares=14),
#  DollarsAndShares(dollars=104.7763089235624, shares=21),
#  DollarsAndShares(dollars=104.6959763174413, shares=28),
#  DollarsAndShares(dollars=104.59657611485054, shares=25),
#  DollarsAndShares(dollars=104.54066115522073, shares=28),
#  DollarsAndShares(dollars=104.53459203827975, shares=17),
#  DollarsAndShares(dollars=104.51951341644933, shares=14),
#  DollarsAndShares(dollars=104.4102371787998, shares=9),
#  DollarsAndShares(dollars=104.38677175251384, shares=29),
#  DollarsAndShares(dollars=104.29248725432073, shares=38),
#  DollarsAndShares(dollars=104.27367496768316, shares=18),
#  DollarsAndShares(dollars=104.223033590686, shares=18),
#  DollarsAndShares(dollars=104.2029981600773, shares=32),
#  DollarsAndShares(dollars=104.17415149535282, shares=23),
#  DollarsAndShares(dollars=104.16398331863246, shares=13),
#  DollarsAndShares(dollars=104.11546079432021, shares=20),
#  DollarsAndShares(dollars=104.09053649565274, shares=8),
#  DollarsAndShares(dollars=103.97283116684953, shares=14),
#  DollarsAndShares(dollars=103.97080378048639, shares=11),
#  DollarsAndShares(dollars=103.90228097578301, shares=19),
#  DollarsAndShares(dollars=103.8898044580939, shares=23),
#  DollarsAndShares(dollars=103.87983311606592, shares=11),
#  DollarsAndShares(dollars=103.80308906136676, shares=17),
#  DollarsAndShares(dollars=103.7847624940925, shares=35),
#  DollarsAndShares(dollars=103.75049716958252, shares=18),
#  DollarsAndShares(dollars=103.70020619177018, shares=20),
#  DollarsAndShares(dollars=103.67026793615878, shares=41),
#  DollarsAndShares(dollars=103.59573539554084, shares=25),
#  DollarsAndShares(dollars=103.58092545718215, shares=20),
#  DollarsAndShares(dollars=103.5315575709837, shares=31),
#  DollarsAndShares(dollars=103.47814419378686, shares=27),
#  DollarsAndShares(dollars=103.47191868607811, shares=17),
#  DollarsAndShares(dollars=103.46596136367621, shares=24),
#  DollarsAndShares(dollars=103.26266562721204, shares=13),
#  DollarsAndShares(dollars=103.22809164890745, shares=16),
#  DollarsAndShares(dollars=103.2060454734619, shares=25),
#  DollarsAndShares(dollars=103.20129462409119, shares=10),
#  DollarsAndShares(dollars=103.09618139013028, shares=25),
#  DollarsAndShares(dollars=103.08189254114592, shares=30),
#  DollarsAndShares(dollars=103.03091755369987, shares=28),
#  DollarsAndShares(dollars=103.02072497354358, shares=20),
#  DollarsAndShares(dollars=102.92006097867227, shares=24),
#  DollarsAndShares(dollars=102.88864377610528, shares=23),
#  DollarsAndShares(dollars=102.87504061497177, shares=8),
#  DollarsAndShares(dollars=102.84424734978556, shares=13),
#  DollarsAndShares(dollars=102.7718106617462, shares=29),
#  DollarsAndShares(dollars=102.75154604207644, shares=16),
#  DollarsAndShares(dollars=102.67197683375943, shares=25),
#  DollarsAndShares(dollars=102.662068723771, shares=25),
#  DollarsAndShares(dollars=102.65930308791997, shares=31),
#  DollarsAndShares(dollars=102.58203091918787, shares=16),
#  DollarsAndShares(dollars=102.56639023198625, shares=37),
#  DollarsAndShares(dollars=102.4688898068869, shares=22),
#  DollarsAndShares(dollars=102.43208842537517, shares=28),
#  DollarsAndShares(dollars=102.38127513633461, shares=20),
#  DollarsAndShares(dollars=102.36997248236942, shares=17),
#  DollarsAndShares(dollars=102.34706719929054, shares=35),
#  DollarsAndShares(dollars=102.32804528717485, shares=12),
#  DollarsAndShares(dollars=102.3266561304542, shares=5),
#  DollarsAndShares(dollars=102.27824652529077, shares=32),
#  DollarsAndShares(dollars=102.23451450776449, shares=13),
#  DollarsAndShares(dollars=102.22612984409213, shares=13),
#  DollarsAndShares(dollars=102.18864335607007, shares=21),
#  DollarsAndShares(dollars=102.11536548871635, shares=30),
#  DollarsAndShares(dollars=102.10974603330237, shares=26),
#  DollarsAndShares(dollars=102.045249565232, shares=17),
#  DollarsAndShares(dollars=102.0265746079935, shares=7),
#  DollarsAndShares(dollars=102.02348051347555, shares=19),
#  DollarsAndShares(dollars=101.91716026893751, shares=30),
#  DollarsAndShares(dollars=101.85198298718498, shares=22),
#  DollarsAndShares(dollars=101.84468790331364, shares=23),
#  DollarsAndShares(dollars=101.82928672387116, shares=22),
#  DollarsAndShares(dollars=101.77658379442312, shares=34),
#  DollarsAndShares(dollars=101.73407933947261, shares=19),
#  DollarsAndShares(dollars=101.7017666564856, shares=1),
#  DollarsAndShares(dollars=101.66958572116069, shares=29),
#  DollarsAndShares(dollars=101.6384302946817, shares=17),
#  DollarsAndShares(dollars=101.58398866535406, shares=37),
#  DollarsAndShares(dollars=101.52491862699533, shares=30),
#  DollarsAndShares(dollars=101.51770205940555, shares=15),
#  DollarsAndShares(dollars=101.48810272629451, shares=31),
#  DollarsAndShares(dollars=101.41949761768282, shares=36),
#  DollarsAndShares(dollars=101.39749653046215, shares=20),
#  DollarsAndShares(dollars=101.37604871881423, shares=24),
#  DollarsAndShares(dollars=101.37115014883005, shares=20),
#  DollarsAndShares(dollars=101.30596811651462, shares=7),
#  DollarsAndShares(dollars=101.25905613935281, shares=10),
#  DollarsAndShares(dollars=101.25545586460416, shares=15),
#  DollarsAndShares(dollars=101.21266056524397, shares=15),
#  DollarsAndShares(dollars=101.1755979004214, shares=26),
#  DollarsAndShares(dollars=101.14087707858461, shares=32),
#  DollarsAndShares(dollars=101.0832152031218, shares=19),
#  DollarsAndShares(dollars=101.06936666758246, shares=21),
#  DollarsAndShares(dollars=101.04876519516203, shares=6),
#  DollarsAndShares(dollars=100.99876254478708, shares=20),
#  DollarsAndShares(dollars=100.9942163637794, shares=20),
#  DollarsAndShares(dollars=100.86050211956191, shares=9),
#  DollarsAndShares(dollars=100.85246302573259, shares=31),
#  DollarsAndShares(dollars=100.71072003440183, shares=25),
#  DollarsAndShares(dollars=100.67321565812149, shares=22),
#  DollarsAndShares(dollars=100.65830649154114, shares=14),
#  DollarsAndShares(dollars=100.53011244546552, shares=40),
#  DollarsAndShares(dollars=100.52225542118127, shares=18),
#  DollarsAndShares(dollars=100.51791683527067, shares=32),
#  DollarsAndShares(dollars=100.51627699421547, shares=10),
#  DollarsAndShares(dollars=100.46835648409848, shares=42),
#  DollarsAndShares(dollars=100.44400742134917, shares=27),
#  DollarsAndShares(dollars=100.42986829923832, shares=17),
#  DollarsAndShares(dollars=100.42168555495678, shares=22),
#  DollarsAndShares(dollars=100.39207194261635, shares=22),
#  DollarsAndShares(dollars=100.36988614499487, shares=29),
#  DollarsAndShares(dollars=100.36708986021875, shares=24),
#  DollarsAndShares(dollars=100.19655876627175, shares=22),
#  DollarsAndShares(dollars=99.85169643719587, shares=18),
#  DollarsAndShares(dollars=99.84753767322316, shares=16),
#  DollarsAndShares(dollars=99.8041852262177, shares=17),
#  DollarsAndShares(dollars=99.63768789946631, shares=29),
#  DollarsAndShares(dollars=99.28361573843232, shares=39),
#  DollarsAndShares(dollars=99.11265921411466, shares=24),
#  DollarsAndShares(dollars=99.10877130250071, shares=29),
#  DollarsAndShares(dollars=98.80426653176431, shares=20),
#  DollarsAndShares(dollars=98.75679092363717, shares=17),
#  DollarsAndShares(dollars=98.73338996107844, shares=29),
#  DollarsAndShares(dollars=98.66429175555999, shares=18),
#  DollarsAndShares(dollars=98.64683430188538, shares=9),
#  DollarsAndShares(dollars=98.60313577136651, shares=4),
#  DollarsAndShares(dollars=98.55771553943315, shares=21),
#  DollarsAndShares(dollars=98.54195223418947, shares=18),
#  DollarsAndShares(dollars=98.54000178094599, shares=21),
#  DollarsAndShares(dollars=98.46767309487139, shares=28),
#  DollarsAndShares(dollars=98.46330681438653, shares=25),
#  DollarsAndShares(dollars=98.46200848305972, shares=26),
#  DollarsAndShares(dollars=98.42782787661842, shares=32),
#  DollarsAndShares(dollars=98.28865920620848, shares=14),
#  DollarsAndShares(dollars=98.28580826983298, shares=32),
#  DollarsAndShares(dollars=98.21740694642658, shares=18),
#  DollarsAndShares(dollars=98.16147671788138, shares=17),
#  DollarsAndShares(dollars=98.14156565819006, shares=28),
#  DollarsAndShares(dollars=98.12338492332252, shares=15),
#  DollarsAndShares(dollars=98.10294905798042, shares=11),
#  DollarsAndShares(dollars=98.0808205200367, shares=11),
#  DollarsAndShares(dollars=98.06289948349323, shares=23),
#  DollarsAndShares(dollars=97.98837623874908, shares=15),
#  DollarsAndShares(dollars=97.97241166631186, shares=10),
#  DollarsAndShares(dollars=97.9701185021506, shares=25),
#  DollarsAndShares(dollars=97.92362873179152, shares=2),
#  DollarsAndShares(dollars=97.90518357609557, shares=27),
#  DollarsAndShares(dollars=97.89274616594192, shares=16),
#  DollarsAndShares(dollars=97.86993500499288, shares=33),
#  DollarsAndShares(dollars=97.8572723101179, shares=18),
#  DollarsAndShares(dollars=97.84112835775483, shares=17),
#  DollarsAndShares(dollars=97.78185012821989, shares=21),
#  DollarsAndShares(dollars=97.77491645587791, shares=36),
#  DollarsAndShares(dollars=97.71394985666497, shares=6),
#  DollarsAndShares(dollars=97.6735353539985, shares=13),
#  DollarsAndShares(dollars=97.66942453394024, shares=17),
#  DollarsAndShares(dollars=97.64859185955613, shares=25),
#  DollarsAndShares(dollars=97.62065108831479, shares=32),
#  DollarsAndShares(dollars=97.5921143328165, shares=14),
#  DollarsAndShares(dollars=97.5668610924503, shares=14),
#  DollarsAndShares(dollars=97.38248945981238, shares=2),
#  DollarsAndShares(dollars=97.31103375689507, shares=12),
#  DollarsAndShares(dollars=97.2932218150901, shares=20),
#  DollarsAndShares(dollars=97.27317852134665, shares=26),
#  DollarsAndShares(dollars=97.26566446148064, shares=23),
#  DollarsAndShares(dollars=97.25575726926179, shares=5),
#  DollarsAndShares(dollars=97.1879236626289, shares=7),
#  DollarsAndShares(dollars=97.18570164379624, shares=33),
#  DollarsAndShares(dollars=97.12846865814213, shares=19),
#  DollarsAndShares(dollars=97, shares=95),
#  DollarsAndShares(dollars=96.9338721002992, shares=27),
#  DollarsAndShares(dollars=96.92812117709768, shares=21),
#  DollarsAndShares(dollars=96.79866303440633, shares=22),
#  DollarsAndShares(dollars=96.71349371202832, shares=24),
#  DollarsAndShares(dollars=96.70981547608903, shares=16),
#  DollarsAndShares(dollars=96.70583385061936, shares=29),
#  DollarsAndShares(dollars=96.64002720915704, shares=28),
#  DollarsAndShares(dollars=96.5833779049812, shares=17),
#  DollarsAndShares(dollars=96.58227320304889, shares=21),
#  DollarsAndShares(dollars=96.57370581230246, shares=39),
#  DollarsAndShares(dollars=96.5063743377388, shares=2),
#  DollarsAndShares(dollars=96.42562651066491, shares=9),
#  DollarsAndShares(dollars=96.36908258767637, shares=17),
#  DollarsAndShares(dollars=96.3670572561441, shares=28),
#  DollarsAndShares(dollars=96.23936869412006, shares=14),
#  DollarsAndShares(dollars=96.18278264504194, shares=35),
#  DollarsAndShares(dollars=96.17334933966023, shares=24),
#  DollarsAndShares(dollars=96.16586415139246, shares=30),
#  DollarsAndShares(dollars=96.15905458066968, shares=10),
#  DollarsAndShares(dollars=96, shares=93),
#  DollarsAndShares(dollars=95.99697044426506, shares=22),
#  DollarsAndShares(dollars=95.96215692808248, shares=21),
#  DollarsAndShares(dollars=95.94639546139327, shares=10),
#  DollarsAndShares(dollars=95.87290695473817, shares=28),
#  DollarsAndShares(dollars=95.835217823978, shares=5),
#  DollarsAndShares(dollars=95.79205780253106, shares=21),
#  DollarsAndShares(dollars=95.62366557877438, shares=22),
#  DollarsAndShares(dollars=95.54919103825031, shares=29),
#  DollarsAndShares(dollars=95.50013740792214, shares=11),
#  DollarsAndShares(dollars=95.46542484953792, shares=40),
#  DollarsAndShares(dollars=95.4372947458922, shares=20),
#  DollarsAndShares(dollars=95.3992464081776, shares=15),
#  DollarsAndShares(dollars=95.39811129440822, shares=21),
#  DollarsAndShares(dollars=95.29651180948305, shares=12),
#  DollarsAndShares(dollars=95.27689825546798, shares=23),
#  DollarsAndShares(dollars=95.21157734478815, shares=33),
#  DollarsAndShares(dollars=95.10314353670036, shares=32),
#  DollarsAndShares(dollars=95.07307523320571, shares=8),
#  DollarsAndShares(dollars=95, shares=112),
#  DollarsAndShares(dollars=94.90604631390079, shares=15),
#  DollarsAndShares(dollars=94.83237486603677, shares=31),
#  DollarsAndShares(dollars=94.7790103268537, shares=21),
#  DollarsAndShares(dollars=94.76159277867573, shares=23),
#  DollarsAndShares(dollars=94.73198705339836, shares=28),
#  DollarsAndShares(dollars=94.50559252998714, shares=11),
#  DollarsAndShares(dollars=94.32205127440889, shares=12),
#  DollarsAndShares(dollars=94.28126487657661, shares=12),
#  DollarsAndShares(dollars=94.2178224149216, shares=10),
#  DollarsAndShares(dollars=94.1543878735272, shares=13),
#  DollarsAndShares(dollars=94.01488001299485, shares=17),
#  DollarsAndShares(dollars=94.01213556629442, shares=20),
#  DollarsAndShares(dollars=94, shares=86),
#  DollarsAndShares(dollars=93.60416375908923, shares=23),
#  DollarsAndShares(dollars=93.55906472129422, shares=25),
#  DollarsAndShares(dollars=93.53109183914992, shares=37),
#  DollarsAndShares(dollars=93.45082204094165, shares=20),
#  DollarsAndShares(dollars=93.45024389226833, shares=24),
#  DollarsAndShares(dollars=93.38081616089379, shares=19),
#  DollarsAndShares(dollars=93.3352451009095, shares=19),
#  DollarsAndShares(dollars=93.26110994609279, shares=28),
#  DollarsAndShares(dollars=93.17964265398936, shares=14),
#  DollarsAndShares(dollars=93, shares=97),
#  DollarsAndShares(dollars=92.93418346636223, shares=31),
#  DollarsAndShares(dollars=92.39002115355198, shares=1),
#  DollarsAndShares(dollars=92, shares=92),
#  DollarsAndShares(dollars=91.97030481281554, shares=18),
#  DollarsAndShares(dollars=91.96851115044765, shares=15),
#  DollarsAndShares(dollars=91.90705622781938, shares=40),
#  DollarsAndShares(dollars=91, shares=96),
#  DollarsAndShares(dollars=90.30572569160599, shares=26),
#  DollarsAndShares(dollars=90.27882374288963, shares=19),
#  DollarsAndShares(dollars=90.16629207990074, shares=12),
#  DollarsAndShares(dollars=90, shares=97),
#  DollarsAndShares(dollars=89, shares=110),
#  DollarsAndShares(dollars=88, shares=92),
#  DollarsAndShares(dollars=87, shares=94),
#  DollarsAndShares(dollars=86, shares=93)]
#
# Asks
#
# [DollarsAndShares(dollars=118.76069683331785, shares=17),
#  DollarsAndShares(dollars=121.88236718516481, shares=19),
#  DollarsAndShares(dollars=123.42274687972161, shares=23),
#  DollarsAndShares(dollars=124.32299149366922, shares=11),
#  DollarsAndShares(dollars=125.61558808939517, shares=23),
#  DollarsAndShares(dollars=126.41389900820396, shares=27),
#  DollarsAndShares(dollars=126.42042109650042, shares=16),
#  DollarsAndShares(dollars=126.42407333402382, shares=19),
#  DollarsAndShares(dollars=126.4804369062606, shares=23),
#  DollarsAndShares(dollars=126.56047242174334, shares=22),
#  DollarsAndShares(dollars=126.58507866140323, shares=16),
#  DollarsAndShares(dollars=126.61881693426491, shares=26),
#  DollarsAndShares(dollars=126.65276554380532, shares=30),
#  DollarsAndShares(dollars=126.80619190320276, shares=24),
#  DollarsAndShares(dollars=126.81866406409821, shares=39),
#  DollarsAndShares(dollars=126.84987323120178, shares=22),
#  DollarsAndShares(dollars=126.89199934488772, shares=18),
#  DollarsAndShares(dollars=126.99886743426715, shares=14),
#  DollarsAndShares(dollars=127, shares=96),
#  DollarsAndShares(dollars=127.03493850641028, shares=20),
#  DollarsAndShares(dollars=127.05178683068496, shares=26),
#  DollarsAndShares(dollars=127.07830793575984, shares=18),
#  DollarsAndShares(dollars=127.08555144596002, shares=14),
#  DollarsAndShares(dollars=127.1111367653193, shares=24),
#  DollarsAndShares(dollars=127.14276873528941, shares=15),
#  DollarsAndShares(dollars=127.29882520783023, shares=12),
#  DollarsAndShares(dollars=127.36604800416781, shares=17),
#  DollarsAndShares(dollars=127.43229295641785, shares=16),
#  DollarsAndShares(dollars=127.54643466258491, shares=29),
#  DollarsAndShares(dollars=127.5711959688138, shares=37),
#  DollarsAndShares(dollars=127.59553770259755, shares=9),
#  DollarsAndShares(dollars=127.7317276793739, shares=9),
#  DollarsAndShares(dollars=127.74950609729777, shares=15),
#  DollarsAndShares(dollars=127.78091906767477, shares=16),
#  DollarsAndShares(dollars=127.80971031313905, shares=19),
#  DollarsAndShares(dollars=127.977804713291, shares=19),
#  DollarsAndShares(dollars=128, shares=112),
#  DollarsAndShares(dollars=128.00169580282704, shares=25),
#  DollarsAndShares(dollars=128.01865934130336, shares=25),
#  DollarsAndShares(dollars=128.03083251774427, shares=11),
#  DollarsAndShares(dollars=128.13836918487127, shares=15),
#  DollarsAndShares(dollars=128.36607867440713, shares=16),
#  DollarsAndShares(dollars=128.48211491304747, shares=17),
#  DollarsAndShares(dollars=128.61244117968673, shares=22),
#  DollarsAndShares(dollars=128.66409343053417, shares=10),
#  DollarsAndShares(dollars=128.7403816751342, shares=11),
#  DollarsAndShares(dollars=128.77998849342868, shares=30),
#  DollarsAndShares(dollars=128.8850094885915, shares=15),
#  DollarsAndShares(dollars=128.9638419749682, shares=23),
#  DollarsAndShares(dollars=129, shares=102),
#  DollarsAndShares(dollars=129.03590184919585, shares=20),
#  DollarsAndShares(dollars=129.0994550665883, shares=19),
#  DollarsAndShares(dollars=129.17854046779786, shares=18),
#  DollarsAndShares(dollars=129.17926486016563, shares=26),
#  DollarsAndShares(dollars=129.18844708607207, shares=30),
#  DollarsAndShares(dollars=129.21047629239885, shares=8),
#  DollarsAndShares(dollars=129.37944461774623, shares=13),
#  DollarsAndShares(dollars=129.51979543214273, shares=22),
#  DollarsAndShares(dollars=129.56551246175408, shares=20),
#  DollarsAndShares(dollars=129.92317243322745, shares=29),
#  DollarsAndShares(dollars=129.99931670424317, shares=28),
#  DollarsAndShares(dollars=130, shares=104),
#  DollarsAndShares(dollars=130.06689639693562, shares=16),
#  DollarsAndShares(dollars=130.07509786118572, shares=10),
#  DollarsAndShares(dollars=130.18321983055046, shares=19),
#  DollarsAndShares(dollars=130.2442196845642, shares=16),
#  DollarsAndShares(dollars=130.40513671672335, shares=23),
#  DollarsAndShares(dollars=130.52353330608187, shares=21),
#  DollarsAndShares(dollars=130.54523157698662, shares=17),
#  DollarsAndShares(dollars=130.71345067266444, shares=15),
#  DollarsAndShares(dollars=130.94256621123984, shares=30),
#  DollarsAndShares(dollars=131, shares=107),
#  DollarsAndShares(dollars=131.13007996324268, shares=20),
#  DollarsAndShares(dollars=131.14180238243, shares=13),
#  DollarsAndShares(dollars=131.23783379024954, shares=18),
#  DollarsAndShares(dollars=131.23978495729185, shares=27),
#  DollarsAndShares(dollars=131.2925569352576, shares=27),
#  DollarsAndShares(dollars=131.30904140193556, shares=20),
#  DollarsAndShares(dollars=131.44346484755292, shares=11),
#  DollarsAndShares(dollars=131.57570795228116, shares=15),
#  DollarsAndShares(dollars=131.75480412182063, shares=17),
#  DollarsAndShares(dollars=132, shares=108),
#  DollarsAndShares(dollars=132.03801825939152, shares=21),
#  DollarsAndShares(dollars=132.10514359694182, shares=21),
#  DollarsAndShares(dollars=132.28433802119284, shares=21),
#  DollarsAndShares(dollars=132.3192196061292, shares=25),
#  DollarsAndShares(dollars=132.34534112687726, shares=17),
#  DollarsAndShares(dollars=132.35173573871583, shares=8),
#  DollarsAndShares(dollars=132.36209064686315, shares=14),
#  DollarsAndShares(dollars=132.38072272290063, shares=19),
#  DollarsAndShares(dollars=132.47998621200574, shares=28),
#  DollarsAndShares(dollars=132.90980589157965, shares=24),
#  DollarsAndShares(dollars=133, shares=113),
#  DollarsAndShares(dollars=133.0940527521411, shares=20),
#  DollarsAndShares(dollars=133.21967537051106, shares=18),
#  DollarsAndShares(dollars=133.7255482218538, shares=24),
#  DollarsAndShares(dollars=133.8610886980024, shares=19),
#  DollarsAndShares(dollars=134, shares=104),
#  DollarsAndShares(dollars=134.105514020451, shares=13),
#  DollarsAndShares(dollars=134.19130678408587, shares=15),
#  DollarsAndShares(dollars=134.63433728997424, shares=25),
#  DollarsAndShares(dollars=134.6762388907899, shares=22),
#  DollarsAndShares(dollars=135.20093788142026, shares=25),
#  DollarsAndShares(dollars=135.32271829524106, shares=14),
#  DollarsAndShares(dollars=136.59140068675026, shares=28),
#  DollarsAndShares(dollars=137.0892231380381, shares=6),
#  DollarsAndShares(dollars=137.20790260073605, shares=21),
#  DollarsAndShares(dollars=137.95362867712893, shares=21),
#  DollarsAndShares(dollars=138.9129919439266, shares=16),
#  DollarsAndShares(dollars=139.03792433810992, shares=20),
#  DollarsAndShares(dollars=142.75624073066444, shares=33),
#  DollarsAndShares(dollars=144.41674485251338, shares=21)]
